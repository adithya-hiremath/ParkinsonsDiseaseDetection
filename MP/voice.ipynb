# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import librosa # type: ignore
import librosa.display # type: ignore
import IPython.display as ipd # type: ignore
import os

# %%
for file in os.listdir('VOICE/'):
    print(file)
# Out:
# AH_545616858-3A749CBC-3FEB-4D35-820E-E45C3E5B9B6A.wav
# AH_545622717-461DFFFE-54AF-42AF-BA78-528BD505D624.wav
# AH_545622718-C052AD58-5E6B-4ADC-855C-F76B66BAFA6E.wav
# AH_545622719-52C23861-6E0D-41E0-A3D8-9358C28C019B.wav
# AH_545622720-E1486AF6-8C95-47EB-829B-4D62698C987A.wav
# AH_545622722-3C79DA68-36BB-43A2-B29C-61AEF480E07E.wav
# AH_545629296-C2C009C6-8C17-42EA-B6BE-362942FC4692.wav
# AH_545643618-82A143AC-B643-4273-A923-C42A83AEEC5F.wav
# AH_545648867-CB17D873-1CEA-492A-B5B0-93C7463F516C.wav
# AH_545692309-EA8C4DC0-9B2A-4CC7-A490-851A2129A733.wav
# AH_545692315-C2972597-9AEC-4060-A186-F1F59340640C.wav
# AH_545713221-1E77C030-4558-4A88-B1A2-6AB777ACAE61.wav
# AH_545713222-DA13DC3A-F24B-454E-984F-19DF19328D39.wav
# AH_545713223-E6D59EE5-4C3F-4B40-AE8F-0657EF94DB66.wav
# AH_545713224-1B3708B0-8792-4FEE-B03B-C7CB9CB03D58.wav
# AH_545743929-E2EAE1A3-7E46-4DCF-8DB7-37A5CA47DB9D.wav
# AH_545753013-FCFF8F46-08FF-4C87-B443-D2039E5DA945.wav
# ...

# %%
ipd.Audio('VOICE\AH_545616858-3A749CBC-3FEB-4D35-820E-E45C3E5B9B6A.wav')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Akash R H\AppData\Local\Temp\ipykernel_19564\2873573121.py:1: SyntaxWarning: invalid escape sequence '\A'
#   ipd.Audio('VOICE\AH_545616858-3A749CBC-3FEB-4D35-820E-E45C3E5B9B6A.wav')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio('VOICE\AH_545847410-D1BA3BB4-1F61-44CA-ACDE-455A8E97E04B.wav')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Akash R H\AppData\Local\Temp\ipykernel_19564\3931652135.py:1: SyntaxWarning: invalid escape sequence '\A'
#   ipd.Audio('VOICE\AH_545847410-D1BA3BB4-1F61-44CA-ACDE-455A8E97E04B.wav')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
import numpy as np # type: ignore

def feature_extraction(audio_path):

    features = np.random.rand(22)
    
    return features

features = {}
directory = 'VOICE/'

for audio in os.listdir(directory):
    audio_path = os.path.join(directory, audio)
    if os.path.isfile(audio_path):
        features[audio_path] = feature_extraction(audio_path)

feature_array = np.array(list(features.values()))

# %%
audio_path
# Out:
# 'VOICE/AH_545880204-EE87D3E2-0D4C-4EAA-ACD7-C3F177AFF62F.wav'

# %%
features[audio_path], len(features[audio_path])
# Out:
# (array([0.17223632, 0.65552933, 0.69222173, 0.25613756, 0.8472054 ,
#         0.60873434, 0.26949614, 0.96034033, 0.39330236, 0.35716865,
#         0.9883468 , 0.31259185, 0.82126931, 0.85155364, 0.42073766,
#         0.91590881, 0.56367091, 0.55575328, 0.56105108, 0.25793832,
#         0.61785276, 0.06674562]),
#  22)
