# %%
import numpy as np # type: ignore

import pandas as pd # type: ignore

parkinson = pd.read_csv('parkinsons.data')
parkinson.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson.shape
# Out:
# (195, 24)

# %%
parkinson.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson.duplicated().sum()
# Out:
# 0

# %%
parkinson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinson['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinson_numeric = parkinson.drop(columns=['name'])

status_mean = parkinson_numeric.groupby('status').mean()

print(status_mean)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
X = parkinson.drop(['status','name'],axis=1)
Y = parkinson['status']

# %%
X.shape
# Out:
# (195, 22)

# %%
Y.shape
# Out:
# (195,)

# %%
from sklearn.model_selection import train_test_split # type: ignore

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler # type: ignore
scalar = StandardScaler()

# %%
scalar.fit(X_train)
X_train = scalar.transform(X_train)
X_test = scalar.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.63239631, -0.02731081, -0.87985049, ..., -0.97586547,
#         -0.55160318,  0.07769494],
#        [-1.05512719, -0.83337041, -0.9284778 , ...,  0.3981808 ,
#         -0.61014073,  0.39291782],
#        [ 0.02996187, -0.29531068, -1.12211107, ..., -0.43937044,
#         -0.62849605, -0.50948408],
#        ...,
#        [-0.9096785 , -0.6637302 , -0.160638  , ...,  1.22001022,
#         -0.47404629, -0.2159482 ],
#        [-0.35977689,  0.19731822, -0.79063679, ..., -0.17896029,
#         -0.47272835,  0.28181221],
#        [ 1.01957066,  0.19922317, -0.61914972, ..., -0.716232  ,
#          1.23632066, -0.05829386]])

# %%
from sklearn.metrics import accuracy_score # type: ignore
from sklearn.metrics import f1_score # type: ignore
from sklearn.metrics import log_loss # type: ignore
from sklearn.metrics import precision_score # type: ignore
from sklearn.metrics import confusion_matrix # type: ignore
from sklearn.metrics import recall_score # type: ignore
from sklearn.metrics import mean_absolute_error # type: ignore

from sklearn.linear_model import LogisticRegression # type: ignore
from sklearn.neighbors import KNeighborsClassifier # type: ignore
from sklearn.svm import SVC # type: ignore
from sklearn.naive_bayes import GaussianNB # type: ignore
from sklearn.tree import DecisionTreeClassifier # type: ignore
from sklearn.ensemble import RandomForestClassifier # type: ignore
from sklearn.ensemble import GradientBoostingClassifier # type: ignore
from sklearn.neural_network import MLPClassifier # type: ignore


models = {
                "Logistic Regression": LogisticRegression(),
                "K-Neighbor Classifier": KNeighborsClassifier(n_neighbors=1),
                "Support Vector Machine Classifier": SVC(kernel = "poly",degree=3),
                "Gaussian Naive Bayes": GaussianNB(),
                'Decision Tree Classifier':DecisionTreeClassifier(),
                'Random Forest Classifier':RandomForestClassifier(),
                'Gradient Boosting Classifier': GradientBoostingClassifier(),
                'Neural Network MLP':  MLPClassifier(),
}

for name, model in models.items():
    model.fit(X_train,y_train)
    y_predict = model.predict(X_test)
    
    
    print(f"{name} Accuracy :",accuracy_score(y_test,y_predict))
    print(f"{name} F1 Score :",f1_score(y_test,y_predict))
    print(f"{name} Precision Score :",precision_score(y_test,y_predict))
    print(f"{name} Log Loss :",log_loss(y_test,y_predict))
    print(f"{name} Confussion Matrix :",confusion_matrix(y_test,y_predict))
    print(f"{name} Recall Score :",recall_score(y_test,y_predict))
    print(f"{name} Mean Absolute Error :",mean_absolute_error(y_test,y_predict))
    print("_____________________________________________________________________________________________________________________________________________________________________")
# Out:
# Logistic Regression Accuracy : 0.8205128205128205
# Logistic Regression F1 Score : 0.8852459016393442
# Logistic Regression Precision Score : 0.9
# Logistic Regression Log Loss : 6.469373685226156
# Logistic Regression Confussion Matrix : [[ 5  3]
#  [ 4 27]]
# Logistic Regression Recall Score : 0.8709677419354839
# Logistic Regression Mean Absolute Error : 0.1794871794871795
# _____________________________________________________________________________________________________________________________________________________________________
# K-Neighbor Classifier Accuracy : 0.7948717948717948
# K-Neighbor Classifier F1 Score : 0.8518518518518519
# K-Neighbor Classifier Precision Score : 1.0
# K-Neighbor Classifier Log Loss : 7.393569925972749
# K-Neighbor Classifier Confussion Matrix : [[ 8  0]
#  [ 8 23]]
# K-Neighbor Classifier Recall Score : 0.7419354838709677
# K-Neighbor Classifier Mean Absolute Error : 0.20512820512820512
# ...

# %%
X_train[10]
# Out:
# array([-1.61117839, -0.92775403, -0.72026757, -0.20821375,  0.41615668,
#        -0.20846279, -0.07682535, -0.20747159, -0.1885993 , -0.2390257 ,
#        -0.20985889, -0.18948669, -0.18258563, -0.20985389, -0.36282408,
#        -0.04495642,  0.80958229,  1.36213302,  0.62900548,  1.6260001 ,
#         0.63043367,  0.72522644])

# %%
X_train[11]
# Out:
# array([-0.16928939, -0.4011683 ,  0.59354573, -0.59748614, -0.67219944,
#        -0.54195532, -0.54284284, -0.54303295, -0.49370138, -0.48523084,
#        -0.46141621, -0.42764271, -0.48494853, -0.46172412, -0.48587856,
#         0.29906709, -1.56924345,  0.70161369, -0.5391479 , -1.36501559,
#        -0.46395466, -0.55714827])

# %%
svc = SVC()
svc.fit(X_train,y_train)
y_predict = svc.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.8974358974358975

# %%
input_data = ( 1.03983688,  0.17237666,  1.67879945, -0.83410268, -0.94428847,
       -0.73207722, -0.75558996, -0.73211087, -0.93702927, -0.90522785,
       -0.94302224, -0.83727105, -0.87945488, -0.94333241, -0.59315683,
        1.97537236, -0.29114466,  0.35627085, -1.24057161, -0.59088115,
       -2.2231008 , -1.20119397)

np_data = np.asanyarray(input_data)
prediction = svc.predict(np_data.reshape(1,-1))

if prediction == 1:
    print("this person has parkinson disease")
else:
    print("this person has no parkinson disease")
# Out:
# this person has no parkinson disease

# %%
input_data = (     0.63239631, -0.02731081, -0.87985049,  0.36806203,  0.14406765,
        0.49280653,  0.30476869,  0.49170115, -0.3137565 , -0.32592164,
       -0.25848708, -0.23791175, -0.33873289, -0.25879402, -0.2113724 ,
       -0.61257363,  0.87112118,  0.24786644,  0.19888239, -0.97586547,
       -0.55160318,  0.07769494)

np_data = np.asanyarray(input_data)
prediction = svc.predict(np_data.reshape(1,-1))

if prediction == 1:
    print("this person has parkinson disease")
else:
    print("this person has no parkinson disease")
# Out:
# this person has parkinson disease

# %%
import pickle
pickle.dump(svc,open('model.pkl','wb'))

# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
import seaborn as sns # type: ignore

parkinson = pd.read_csv('parkinsons.data')

X = parkinson.drop(['status','name'],axis=1)
y = parkinson['status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

models = {
                "Logistic Regression": LogisticRegression(),
                "K-Neighbor Classifier": KNeighborsClassifier(n_neighbors=1),
                "Support Vector Machine Classifier": SVC(kernel = "poly",degree=3),
                "Gaussian Naive Bayes": GaussianNB(),
                'Decision Tree Classifier':DecisionTreeClassifier(),
                'Random Forest Classifier':RandomForestClassifier(),
                'Gradient Boosting Classifier': GradientBoostingClassifier(),
                'Neural Network MLP':  MLPClassifier()
}

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)

    logloss = log_loss(y_test, y_predict)
    accuracy = accuracy_score(y_test, y_predict)
    precision = precision_score(y_test, y_predict, average='weighted')
    recall = recall_score(y_test, y_predict, average='weighted')
    f1 = f1_score(y_test, y_predict, average='weighted')
    mae = mean_absolute_error(y_test, y_predict)
    cm = confusion_matrix(y_test, y_predict)

    results.append({
                        'Model': name,
                        'Log Loss': logloss,
                        'Accuracy': accuracy,
                        'Precision': precision,
                        'Recall': recall,
                        'F1 Score': f1,
                        'MAE': mae,
                        'Confusion Matrix': cm
    })

results_df = pd.DataFrame(results)

fig, axes = plt.subplots(3, 2, figsize=(15, 15))
fig.suptitle('Model Performance Metrics')

sns.barplot(ax=axes[0, 0], x='Log Loss', y='Model', data=results_df)
axes[0, 0].set_title('Log Loss')

sns.barplot(ax=axes[0, 1], x='Accuracy', y='Model', data=results_df)
axes[0, 1].set_title('Accuracy')

sns.barplot(ax=axes[1, 0], x='Precision', y='Model', data=results_df)
axes[1, 0].set_title('Precision')

sns.barplot(ax=axes[1, 1], x='Recall', y='Model', data=results_df)
axes[1, 1].set_title('Recall')

sns.barplot(ax=axes[2, 0], x='F1 Score', y='Model', data=results_df)
axes[2, 0].set_title('F1 Score')

sns.barplot(ax=axes[2, 1], x='MAE', y='Model', data=results_df)
axes[2, 1].set_title('Mean Absolute Error')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

n_models = len(models)
n_cols = 2
n_rows = int(np.ceil(n_models / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15,25))
axes = axes.flatten()

for idx, result in enumerate(results):
    cm = result['Confusion Matrix']
    model_name = result['Model']

    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx])
    axes[idx].set_title(f'Confusion Matrix for {model_name}')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

for i in range(len(results), n_rows * n_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Akash R H\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Akash R H\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
